# %%
import numpy as np
from helper_functions import recall, recall12, mean_recall, calculate_recall_per_customer_batch
from helper_functions import read_parquet_datasets
from candidate_generation import get_candidates
import pandas as pd
import time

transactions, customers, articles = read_parquet_datasets()

transactions_copy = transactions.copy()
validation = transactions[transactions.week == transactions.week.max()]

test_week = transactions.week.max() + 1
transactions = transactions[transactions.week > transactions.week.max() - 10]

# %% [markdown]
# # Generating candidates

# %% [markdown]
# ### Last purchase candidates

# %%
c2weeks = transactions.groupby('customer_id')['week'].unique()
c2weeks2shifted_weeks = {}

for c_id, weeks in c2weeks.items():
    c2weeks2shifted_weeks[c_id] = {}
    for i in range(weeks.shape[0]-1):
        c2weeks2shifted_weeks[c_id][weeks[i]] = weeks[i+1]
    c2weeks2shifted_weeks[c_id][weeks[-1]] = test_week
    
candidates_last_purchase = transactions.copy()
weeks = []
for i, (c_id, week) in enumerate(zip(transactions['customer_id'], transactions['week'])):
    weeks.append(c2weeks2shifted_weeks[c_id][week])
candidates_last_purchase.week=weeks

# %% [markdown]
# ### Create three features: age, index_group_name and mean purchase price of the customer.

# %%
# first create mean price per customer
mean_price_per_c = transactions.groupby('customer_id')['price'].mean().rename('mean_price_per_c').reset_index()
# figure out the customers preferred index group name by looking at past transactions articles' index_group_name
temp_transactions = pd.merge(transactions, articles[['article_id', 'index_group_name']], on='article_id', how='left')
# per customer count the number of purchases of each index_group_name
c2index_group_name = temp_transactions.groupby('customer_id')['index_group_name'].value_counts().rename('count').reset_index()
c2index_group_name = c2index_group_name.sort_values('count', ascending=False).groupby('customer_id').head(1).rename(columns={'index_group_name': 'highest_count_ign_per_c'})
# merge the mean_price_per_c and c2index_group_name dataframes
transactions_with_2feat = pd.merge(c2index_group_name[['customer_id', 'highest_count_ign_per_c']], mean_price_per_c, on='customer_id', how='left')

# per article, find the average age of the customers who bought it
transactions_with_age = pd.merge(transactions, customers[['customer_id', 'age']], on='customer_id', how='left')
mean_age_per_article = transactions_with_age.groupby('article_id')['age'].mean().rename('mean_age_per_a').astype('int8').reset_index()

# merge to get the mean_price_per_c, highest_count_ign_per_c and mean_age_per_a columns. This forms the transactions_with_3feat (transactions with three features) dataframe
transactions_with_age_2feat = pd.merge(transactions_with_age, transactions_with_2feat, on='customer_id', how='left')
transactions_with_3feat = pd.merge(transactions_with_age_2feat, mean_age_per_article, on='article_id', how='left')
transactions_with_3feat = pd.merge(transactions_with_3feat, articles[['article_id', 'index_group_name']], on='article_id', how='left') # to get the index_group_name (back)

# %%
transactions_with_3feat
# Out:
#              t_dat           customer_id  article_id     price  \
# 0       2020-07-15       272412481300040   778064028  0.008458
# 1       2020-07-15       272412481300040   816592008  0.016932
# 2       2020-07-15       272412481300040   621381021  0.033881
# 3       2020-07-15       272412481300040   817477003  0.025407
# 4       2020-07-15       272412481300040   899088002  0.025407
# ...            ...                   ...         ...       ...
# 2762867 2020-09-22  18439937050817258297   891591003  0.084729
# 2762868 2020-09-22  18439937050817258297   869706005  0.084729
# 2762869 2020-09-22  18440902715633436014   918894002  0.016932
# 2762870 2020-09-22  18440902715633436014   761269001  0.016932
# 2762871 2020-09-22  18443633011701112574   914868002  0.033881
#
#          sales_channel_id  week  age  highest_count_ign_per_c  \
# 0                       1    95   48                        0
# 1                       1    95   48                        0
# 2                       1    95   48                        0
# 3                       1    95   48                        0
# 4                       1    95   48                        0
# ...                   ...   ...  ...                      ...
# 2762867                 2   104   49                        0
# 2762868                 2   104   49                        0
# 2762869                 1   104   18                        0
# 2762870                 1   104   18                        0
# 2762871                 1   104   58                        0
#
#          mean_price_per_c  mean_age_per_a  index_group_name
# 0                0.030597              32                 0
# 1                0.030597              37                 2
# 2                0.030597              35                 2
# 3                0.030597              33                 0
# 4                0.030597              35                 2
# ...                   ...             ...               ...
# 2762867          0.040379              41                 0
# 2762868          0.040379              39                 0
# 2762869          0.028232              30                 0
# 2762870          0.028232              33                 0
# 2762871          0.032186              33                 2
#
# [2762872 rows x 11 columns]

# %%
# merge t with customers columns customer_id, age on customer_id for later use
t_merged = pd.merge(transactions_with_2feat, customers[['customer_id', 'age']], on='customer_id', how='left')
# Create a DataFrame with unique articles
unique_articles = transactions_with_3feat[['t_dat', 'sales_channel_id', 'article_id', 'price', 'index_group_name', 'week']].drop_duplicates()
# we only keep latest purchase of each article
unique_articles = unique_articles.sort_values('t_dat', ascending=False).drop_duplicates('article_id')

# %% [markdown]
# ### Calculate overall mean recall

# %%
# Define the total number of customers and batch size
total_customers = mean_price_per_c['customer_id'].nunique()
print("Total customers:", total_customers)
batch_size = 1000

topX_price=50 # top x candidates filtered by price columns
topX_age=25 # top x candidates filtered by age columns

# Initialize an empty list to store mean recalls for each batch
mean_recalls = []

batches = mean_price_per_c['customer_id'].unique()

# Iterate over customer batches
for i in range(0, total_customers, batch_size):
    start = time.time()
    start_idx = i
    end_idx = i + batch_size
    
    # Get the current batch of customers
    current_batch = batches[start_idx:end_idx]
    
    # Get candidates for the current batch
    top_candidates_3feat = get_candidates([current_batch], unique_articles, t_merged, mean_age_per_article, topX_price, topX_age)
    
    # Increment the week for the candidates to match the next week
    top_candidates_3feat_prev_week = top_candidates_3feat.copy()
    top_candidates_3feat_prev_week.week += 1
    
    # Calculate mean recall for the current batch
    mean_recall_batch = calculate_recall_per_customer_batch(validation, top_candidates_3feat_prev_week, current_batch, topX_age)
    
    # Append mean recall to the list
    mean_recalls.append(mean_recall_batch)
    
    print(f'Batch {i} processed in {time.time() - start:.2f} seconds')

# Calculate overall mean recall
overall_mean_recall = np.mean(mean_recalls)
print("Overall Mean Recall:", overall_mean_recall)
# Out:
# Total customers: 437365
# Chunk 0 processed in 19.03 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 0 processed in 19.06 seconds
# Chunk 0 processed in 19.00 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 1000 processed in 19.04 seconds
# Chunk 0 processed in 18.87 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 2000 processed in 18.91 seconds
# Chunk 0 processed in 18.61 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 3000 processed in 18.65 seconds
# Chunk 0 processed in 18.89 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 4000 processed in 18.93 seconds
# Chunk 0 processed in 18.32 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 5000 processed in 18.36 seconds
# Chunk 0 processed in 19.42 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 6000 processed in 19.46 seconds
# Chunk 0 processed in 18.96 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 7000 processed in 19.00 seconds
# Chunk 0 processed in 19.24 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 8000 processed in 19.27 seconds
# Chunk 0 processed in 19.71 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 9000 processed in 19.75 seconds
# Chunk 0 processed in 18.51 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 10000 processed in 18.55 seconds
# Chunk 0 processed in 18.28 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 11000 processed in 18.32 seconds
# Chunk 0 processed in 18.38 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 12000 processed in 18.42 seconds
# Chunk 0 processed in 18.46 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 13000 processed in 18.50 seconds
# Chunk 0 processed in 18.36 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 14000 processed in 18.40 seconds
# Chunk 0 processed in 18.35 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 15000 processed in 18.39 seconds
# Chunk 0 processed in 18.82 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 16000 processed in 18.86 seconds
# Chunk 0 processed in 18.70 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 17000 processed in 18.74 seconds
# Chunk 0 processed in 18.13 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 18000 processed in 18.17 seconds
# Chunk 0 processed in 18.55 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 19000 processed in 18.59 seconds
# Chunk 0 processed in 18.14 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 20000 processed in 18.18 seconds
# Chunk 0 processed in 19.41 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 21000 processed in 19.44 seconds
# Chunk 0 processed in 19.71 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 22000 processed in 19.75 seconds
# Chunk 0 processed in 20.69 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 23000 processed in 20.73 seconds
# Chunk 0 processed in 20.55 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 24000 processed in 20.58 seconds
# Chunk 0 processed in 21.19 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 25000 processed in 21.23 seconds
# Chunk 0 processed in 19.55 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 26000 processed in 19.58 seconds
# Chunk 0 processed in 18.58 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 27000 processed in 18.62 seconds
# Chunk 0 processed in 18.53 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 28000 processed in 18.57 seconds
# Chunk 0 processed in 18.82 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 29000 processed in 18.85 seconds
# Chunk 0 processed in 20.34 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 30000 processed in 20.38 seconds
# Chunk 0 processed in 21.14 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 31000 processed in 21.17 seconds
# Chunk 0 processed in 18.58 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 32000 processed in 18.62 seconds
# Chunk 0 processed in 18.74 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 33000 processed in 18.78 seconds
# Chunk 0 processed in 19.31 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 34000 processed in 19.35 seconds
# Chunk 0 processed in 19.80 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 35000 processed in 19.84 seconds
# Chunk 0 processed in 18.64 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 36000 processed in 18.68 seconds
# Chunk 0 processed in 20.20 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 37000 processed in 20.24 seconds
# Chunk 0 processed in 18.59 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 38000 processed in 18.63 seconds
# Chunk 0 processed in 20.29 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 39000 processed in 20.32 seconds
# Chunk 0 processed in 19.12 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 40000 processed in 19.17 seconds
# Chunk 0 processed in 18.79 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 41000 processed in 18.82 seconds
# Chunk 0 processed in 19.57 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 42000 processed in 19.61 seconds
# Chunk 0 processed in 18.98 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 43000 processed in 19.02 seconds
# Chunk 0 processed in 35.30 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 44000 processed in 35.43 seconds
# Chunk 0 processed in 36.03 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 45000 processed in 36.07 seconds
# Chunk 0 processed in 18.54 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 46000 processed in 18.58 seconds
# Chunk 0 processed in 18.31 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 47000 processed in 18.34 seconds
# Chunk 0 processed in 18.59 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 48000 processed in 18.63 seconds
# Chunk 0 processed in 18.92 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 49000 processed in 18.96 seconds
# Chunk 0 processed in 18.83 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 50000 processed in 18.87 seconds
# Chunk 0 processed in 18.93 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 51000 processed in 18.97 seconds
# Chunk 0 processed in 19.40 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 52000 processed in 19.44 seconds
# Chunk 0 processed in 19.16 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 53000 processed in 19.20 seconds
# Chunk 0 processed in 18.74 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 54000 processed in 18.78 seconds
# Chunk 0 processed in 18.55 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 55000 processed in 18.59 seconds
# Chunk 0 processed in 18.61 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 56000 processed in 18.65 seconds
# Chunk 0 processed in 19.27 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 57000 processed in 19.31 seconds
# Chunk 0 processed in 18.88 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 58000 processed in 18.92 seconds
# Chunk 0 processed in 18.94 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 59000 processed in 18.98 seconds
# Chunk 0 processed in 18.33 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 60000 processed in 18.37 seconds
# Chunk 0 processed in 18.82 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 61000 processed in 18.85 seconds
# Chunk 0 processed in 18.16 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 62000 processed in 18.20 seconds
# Chunk 0 processed in 19.30 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 63000 processed in 19.34 seconds
# Chunk 0 processed in 18.75 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 64000 processed in 18.79 seconds
# Chunk 0 processed in 18.87 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 65000 processed in 18.91 seconds
# Chunk 0 processed in 19.12 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 66000 processed in 19.16 seconds
# Chunk 0 processed in 19.07 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 67000 processed in 19.11 seconds
# Chunk 0 processed in 18.85 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 68000 processed in 18.89 seconds
# Chunk 0 processed in 18.42 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 69000 processed in 18.46 seconds
# Chunk 0 processed in 18.36 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 70000 processed in 18.40 seconds
# Chunk 0 processed in 18.43 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 71000 processed in 18.47 seconds
# Chunk 0 processed in 18.13 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 72000 processed in 18.17 seconds
# Chunk 0 processed in 18.45 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 73000 processed in 18.49 seconds
# Chunk 0 processed in 18.57 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 74000 processed in 18.61 seconds
# Chunk 0 processed in 18.83 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 75000 processed in 18.87 seconds
# Chunk 0 processed in 18.39 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 76000 processed in 18.43 seconds
# Chunk 0 processed in 18.39 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 77000 processed in 18.43 seconds
# Chunk 0 processed in 18.38 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 78000 processed in 18.42 seconds
# Chunk 0 processed in 18.21 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 79000 processed in 18.24 seconds
# Chunk 0 processed in 18.53 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 80000 processed in 18.57 seconds
# Chunk 0 processed in 18.66 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 81000 processed in 18.70 seconds
# Chunk 0 processed in 18.51 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 82000 processed in 18.55 seconds
# Chunk 0 processed in 18.14 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 83000 processed in 18.18 seconds
# Chunk 0 processed in 17.88 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 84000 processed in 17.92 seconds
# Chunk 0 processed in 18.36 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 85000 processed in 18.40 seconds
# Chunk 0 processed in 18.83 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 86000 processed in 18.86 seconds
# Chunk 0 processed in 19.14 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 87000 processed in 19.17 seconds
# Chunk 0 processed in 19.78 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 88000 processed in 19.82 seconds
# Chunk 0 processed in 19.25 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 89000 processed in 19.29 seconds
# Chunk 0 processed in 19.14 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 90000 processed in 19.18 seconds
# Chunk 0 processed in 18.79 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 91000 processed in 18.83 seconds
# Chunk 0 processed in 19.11 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 92000 processed in 19.15 seconds
# Chunk 0 processed in 19.05 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 93000 processed in 19.09 seconds
# Chunk 0 processed in 18.42 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 94000 processed in 18.47 seconds
# Chunk 0 processed in 18.49 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 95000 processed in 18.53 seconds
# Chunk 0 processed in 18.74 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 96000 processed in 18.78 seconds
# Chunk 0 processed in 18.40 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 97000 processed in 18.44 seconds
# Chunk 0 processed in 19.11 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 98000 processed in 19.15 seconds
# Chunk 0 processed in 18.91 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 99000 processed in 18.95 seconds
# Chunk 0 processed in 18.80 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 100000 processed in 18.84 seconds
# Chunk 0 processed in 19.35 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 101000 processed in 19.39 seconds
# Chunk 0 processed in 18.68 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 102000 processed in 18.72 seconds
# Chunk 0 processed in 19.09 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 103000 processed in 19.12 seconds
# Chunk 0 processed in 18.91 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 104000 processed in 18.95 seconds
# Chunk 0 processed in 18.98 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 105000 processed in 19.02 seconds
# Chunk 0 processed in 19.11 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 106000 processed in 19.14 seconds
# Chunk 0 processed in 18.72 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 107000 processed in 18.76 seconds
# Chunk 0 processed in 18.73 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 108000 processed in 18.77 seconds
# Chunk 0 processed in 19.08 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 109000 processed in 19.12 seconds
# Chunk 0 processed in 18.94 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 110000 processed in 18.98 seconds
# Chunk 0 processed in 19.05 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 111000 processed in 19.09 seconds
# Chunk 0 processed in 18.73 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 112000 processed in 18.77 seconds
# Chunk 0 processed in 18.95 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 113000 processed in 18.99 seconds
# Chunk 0 processed in 19.49 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 114000 processed in 19.54 seconds
# Chunk 0 processed in 18.98 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 115000 processed in 19.02 seconds
# Chunk 0 processed in 19.00 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 116000 processed in 19.04 seconds
# Chunk 0 processed in 19.60 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 117000 processed in 19.64 seconds
# Chunk 0 processed in 19.15 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 118000 processed in 19.19 seconds
# Chunk 0 processed in 18.78 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 119000 processed in 18.82 seconds
# Chunk 0 processed in 18.93 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 120000 processed in 18.97 seconds
# Chunk 0 processed in 18.96 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 121000 processed in 18.99 seconds
# Chunk 0 processed in 18.63 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 122000 processed in 18.67 seconds
# Chunk 0 processed in 19.12 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 123000 processed in 19.16 seconds
# Chunk 0 processed in 19.18 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 124000 processed in 19.22 seconds
# Chunk 0 processed in 19.25 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 125000 processed in 19.29 seconds
# Chunk 0 processed in 18.72 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 126000 processed in 18.76 seconds
# Chunk 0 processed in 18.85 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 127000 processed in 18.89 seconds
# Chunk 0 processed in 18.69 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 128000 processed in 18.72 seconds
# Chunk 0 processed in 19.27 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 129000 processed in 19.31 seconds
# Chunk 0 processed in 18.97 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 130000 processed in 19.01 seconds
# Chunk 0 processed in 18.80 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 131000 processed in 18.84 seconds
# Chunk 0 processed in 18.93 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 132000 processed in 18.97 seconds
# Chunk 0 processed in 18.82 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 133000 processed in 18.85 seconds
# Chunk 0 processed in 18.75 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 134000 processed in 18.79 seconds
# Chunk 0 processed in 19.09 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 135000 processed in 19.13 seconds
# Chunk 0 processed in 19.12 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 136000 processed in 19.16 seconds
# Chunk 0 processed in 19.37 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 137000 processed in 19.40 seconds
# Chunk 0 processed in 18.78 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 138000 processed in 18.82 seconds
# Chunk 0 processed in 18.83 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 139000 processed in 18.87 seconds
# Chunk 0 processed in 19.03 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 140000 processed in 19.07 seconds
# Chunk 0 processed in 19.00 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 141000 processed in 19.03 seconds
# Chunk 0 processed in 18.45 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 142000 processed in 18.48 seconds
# Chunk 0 processed in 18.66 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 143000 processed in 18.70 seconds
# Chunk 0 processed in 19.31 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 144000 processed in 19.35 seconds
# Chunk 0 processed in 19.26 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 145000 processed in 19.29 seconds
# Chunk 0 processed in 19.12 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 146000 processed in 19.16 seconds
# Chunk 0 processed in 19.32 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 147000 processed in 19.36 seconds
# Chunk 0 processed in 19.02 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 148000 processed in 19.06 seconds
# Chunk 0 processed in 18.93 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 149000 processed in 18.96 seconds
# Chunk 0 processed in 19.02 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 150000 processed in 19.06 seconds
# Chunk 0 processed in 18.96 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 151000 processed in 19.00 seconds
# Chunk 0 processed in 18.87 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 152000 processed in 18.91 seconds
# Chunk 0 processed in 18.94 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 153000 processed in 18.98 seconds
# Chunk 0 processed in 19.02 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 154000 processed in 19.06 seconds
# Chunk 0 processed in 18.61 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 155000 processed in 18.66 seconds
# Chunk 0 processed in 19.21 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 156000 processed in 19.25 seconds
# Chunk 0 processed in 18.55 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 157000 processed in 18.59 seconds
# Chunk 0 processed in 18.94 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 158000 processed in 18.98 seconds
# Chunk 0 processed in 19.27 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 159000 processed in 19.31 seconds
# Chunk 0 processed in 19.08 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 160000 processed in 19.13 seconds
# Chunk 0 processed in 19.18 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 161000 processed in 19.22 seconds
# Chunk 0 processed in 18.86 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 162000 processed in 18.90 seconds
# Chunk 0 processed in 18.91 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 163000 processed in 18.95 seconds
# Chunk 0 processed in 18.66 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 164000 processed in 18.70 seconds
# Chunk 0 processed in 19.17 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 165000 processed in 19.21 seconds
# Chunk 0 processed in 19.05 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 166000 processed in 19.09 seconds
# Chunk 0 processed in 18.86 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 167000 processed in 18.90 seconds
# Chunk 0 processed in 18.56 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 168000 processed in 18.60 seconds
# Chunk 0 processed in 18.85 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 169000 processed in 18.89 seconds
# Chunk 0 processed in 19.29 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 170000 processed in 19.33 seconds
# Chunk 0 processed in 19.45 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 171000 processed in 19.49 seconds
# Chunk 0 processed in 18.77 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 172000 processed in 18.81 seconds
# Chunk 0 processed in 19.65 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 173000 processed in 19.69 seconds
# Chunk 0 processed in 18.88 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 174000 processed in 18.91 seconds
# Chunk 0 processed in 18.94 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 175000 processed in 18.98 seconds
# Chunk 0 processed in 18.77 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 176000 processed in 18.81 seconds
# Chunk 0 processed in 18.75 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 177000 processed in 18.79 seconds
# Chunk 0 processed in 19.38 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 178000 processed in 19.42 seconds
# Chunk 0 processed in 19.55 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 179000 processed in 19.59 seconds
# Chunk 0 processed in 18.80 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 180000 processed in 18.84 seconds
# Chunk 0 processed in 18.73 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 181000 processed in 18.77 seconds
# Chunk 0 processed in 18.68 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 182000 processed in 18.72 seconds
# Chunk 0 processed in 18.32 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 183000 processed in 18.36 seconds
# Chunk 0 processed in 19.17 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 184000 processed in 19.21 seconds
# Chunk 0 processed in 18.78 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 185000 processed in 18.82 seconds
# Chunk 0 processed in 19.06 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 186000 processed in 19.10 seconds
# Chunk 0 processed in 19.19 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 187000 processed in 19.23 seconds
# Chunk 0 processed in 18.93 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 188000 processed in 18.97 seconds
# Chunk 0 processed in 19.08 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 189000 processed in 19.12 seconds
# Chunk 0 processed in 18.93 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 190000 processed in 18.97 seconds
# Chunk 0 processed in 19.48 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 191000 processed in 19.52 seconds
# Chunk 0 processed in 18.72 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 192000 processed in 18.76 seconds
# Chunk 0 processed in 19.16 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 193000 processed in 19.20 seconds
# Chunk 0 processed in 19.16 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 194000 processed in 19.20 seconds
# Chunk 0 processed in 18.96 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 195000 processed in 19.00 seconds
# Chunk 0 processed in 18.45 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 196000 processed in 18.49 seconds
# Chunk 0 processed in 19.29 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 197000 processed in 19.33 seconds
# Chunk 0 processed in 18.72 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 198000 processed in 18.76 seconds
# Chunk 0 processed in 18.98 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 199000 processed in 19.02 seconds
# Chunk 0 processed in 18.95 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 200000 processed in 18.99 seconds
# Chunk 0 processed in 18.53 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 201000 processed in 18.57 seconds
# Chunk 0 processed in 18.88 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 202000 processed in 18.92 seconds
# Chunk 0 processed in 19.22 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 203000 processed in 19.26 seconds
# Chunk 0 processed in 18.69 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 204000 processed in 18.73 seconds
# Chunk 0 processed in 19.32 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 205000 processed in 19.36 seconds
# Chunk 0 processed in 18.69 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 206000 processed in 18.73 seconds
# Chunk 0 processed in 19.02 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 207000 processed in 19.06 seconds
# Chunk 0 processed in 18.98 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 208000 processed in 19.02 seconds
# Chunk 0 processed in 19.46 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 209000 processed in 19.50 seconds
# Chunk 0 processed in 19.62 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 210000 processed in 19.66 seconds
# Chunk 0 processed in 19.13 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 211000 processed in 19.17 seconds
# Chunk 0 processed in 19.88 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 212000 processed in 19.92 seconds
# Chunk 0 processed in 19.19 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 213000 processed in 19.23 seconds
# Chunk 0 processed in 19.36 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 214000 processed in 19.40 seconds
# Chunk 0 processed in 19.92 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 215000 processed in 19.96 seconds
# Chunk 0 processed in 20.65 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 216000 processed in 20.69 seconds
# Chunk 0 processed in 20.63 seconds
# Recall Score on Candidates for Last Week: 0.0
# Batch 217000 processed in 20.67 seconds

# %%
print(mean_recalls)
