# %%
import kaggle
import pandas as pd

# %%
# Get H&M competition
competition = kaggle.api.competition_submissions("h-and-m-personalized-fashion-recommendations")
competition
# Out:
# [35535195,
#  35143175,
#  35139983,
#  35129538,
#  35129469,
#  35129395,
#  35129308,
#  35129201,
#  35129016,
#  35128924,
#  35128845,
#  35128733,
#  35128633,
#  35115893,
#  35115778,
#  35115728,
#  35112930,
#  35112876,
#  35112710,
#  35112526,
#  35110841,
#  35110616,
#  35110257,
#  34812844,
#  34812272,
#  34773407,
#  34491397,
#  34465911,
#  33962158,
#  33961295,
#  33960092,
#  33959870,
#  33958407,
#  33958226,
#  33958113,
#  33931129]

# %%
# Get own submissions
submissions = kaggle.api.competitions_submissions_list("h-and-m-personalized-fashion-recommendations")
submissions
# Out:
# [{'totalBytesNullable': 55878223,
#   'descriptionNullable': 'Experiment 21: Feature baseline [t 3,w 105] [a br,atr] [tc weekly bestsellers,previous purchases] [rc weekly bestsellers,previous purchases] ',
#   'errorDescriptionNullable': '',
#   'fileNameNullable': 'score_experiments_21_submission_t_3w_105_a_bratr_tc_weekly_bestsellersprevious_purchases_rc_weekly_bestsellersprevious_purchases_.csv.gz',
#   'publicScoreNullable': '0.01535',
#   'privateScoreNullable': '0.01487',
#   'submittedByNullable': 'felixvernieuwe2',
#   'submittedByRefNullable': 'felixvernieuwe2',
#   'teamNameNullable': 'FelixVernieuwe2',
#   'urlNullable': '/submissions/35535195/35535195.raw',
#   'ref': 35535195,
#   'totalBytes': 55878223,
#   'hasTotalBytes': True,
#   'date': '2023-12-21T19:56:33.49Z',
#   'description': 'Experiment 21: Feature baseline [t 3,w 105] [a br,atr] [tc weekly bestsellers,previous purchases] [rc weekly bestsellers,previous purchases] ',
#   'hasDescription': True,
# ...

# %%
submissions
submissions[0]["publicScore"], submissions[0]["privateScore"]
# Out:
# ('0.01535', '0.01487')

# %%
leaderboard = pd.DataFrame(leaderboard)
last_submission = leaderboard.iloc[-1]
score = last_submission['score']
