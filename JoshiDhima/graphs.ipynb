# %%
import matplotlib.pyplot as plt
import numpy as np

age_groups = ['18-25', '25-40', '40-60', '>60']
age_group_precisions = [1.100304, 0.688329, 0.601385, 0.273876]
-1, 0.02, 0.04, 0.1, 0.3, 1
avg_price_groups = ['0-11.8', '11.8-23.6', '23.6-59.0', '59.0-177.0', '>177.0']
avg_price_group_precisions = [0.865175, 0.788028, 0.416613, 0.0, 0.0]

max_price_groups = ['0-11.8', '11.8-23.6', '23.6-59.0', '59.0-177.0', '>177.0']
max_price_group_precisions = [0.800631, 1.149788, 0.822542, 0.485207, 0.268519]

most_bought_genders = ['Children', 'Men', 'Women']
most_bought_gender_precisions = [0.930944, 0.591534, 0.780661]

fig, axes = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle('Precision of Bestsellers All Time (Radek) among different customer groups')

axes[0, 0].bar(age_groups, age_group_precisions, color='skyblue')
axes[0, 0].set_title('Precision by Age Group')
axes[0, 0].set_xlabel('Age Group')
axes[0, 0].set_ylabel('Precision (%)')
axes[0, 0].set_ylim(0, max(age_group_precisions) + 0.2)

axes[0, 1].bar(avg_price_groups, avg_price_group_precisions, color='lightgreen')
axes[0, 1].set_title('Precision by Avg Price Group')
axes[0, 1].set_xlabel('Avg Price Group')
axes[0, 1].set_ylabel('Precision (%)')
axes[0, 1].set_ylim(0, max(avg_price_group_precisions) + 0.2)

axes[1, 0].bar(max_price_groups, max_price_group_precisions, color='salmon')
axes[1, 0].set_title('Precision by Max Price Group')
axes[1, 0].set_xlabel('Max Price Group')
axes[1, 0].set_ylabel('Precision (%)')
axes[1, 0].set_ylim(0, max(max_price_group_precisions) + 0.2)

axes[1, 1].bar(most_bought_genders, most_bought_gender_precisions, color='orchid')
axes[1, 1].set_title('Precision by Most Bought Gender')
axes[1, 1].set_xlabel('Most Bought Gender')
axes[1, 1].set_ylabel('Precision (%)')
axes[1, 1].set_ylim(0, max(most_bought_gender_precisions) + 0.2)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
updated_age_group_precisions = [1.411022, 0.856366, 1.363264, 1.526519]
updated_avg_price_group_precisions = [0.739397, 1.169615, 0.490608, 1.176471, 50.000000]
updated_max_price_group_precisions = [0.448296, 1.176352, 1.025290, 0.732952, 1.070370]
updated_most_bought_gender_precisions = [0.560873, 1.579279, 1.116825]

fig, axes = plt.subplots(2, 2, figsize=(15, 10))
fig.suptitle('Precision of Custom Candidate Generation Methods among relevant customer groups')

axes[0, 0].bar(age_groups, updated_age_group_precisions, color='skyblue')
axes[0, 0].set_title('Precision by Age Group')
axes[0, 0].set_xlabel('Age Group')
axes[0, 0].set_ylabel('Precision (%)')
axes[0, 0].set_ylim(0, max(updated_age_group_precisions) + 0.2)

axes[0, 1].bar(avg_price_groups, updated_avg_price_group_precisions, color='lightgreen')
axes[0, 1].set_title('Precision by Avg Price Group')
axes[0, 1].set_xlabel('Avg Price Group')
axes[0, 1].set_ylabel('Precision (%)')
axes[0, 1].set_ylim(0, max(updated_avg_price_group_precisions) + 5)  # Adjusted for the outlier

axes[1, 0].bar(max_price_groups, updated_max_price_group_precisions, color='salmon')
axes[1, 0].set_title('Precision by Max Price Group')
axes[1, 0].set_xlabel('Max Price Group')
axes[1, 0].set_ylabel('Precision (%)')
axes[1, 0].set_ylim(0, max(updated_max_price_group_precisions) + 0.2)

axes[1, 1].bar(most_bought_genders, updated_most_bought_gender_precisions, color='orchid')
axes[1, 1].set_title('Precision by Most Bought Gender')
axes[1, 1].set_xlabel('Most Bought Gender')
axes[1, 1].set_ylabel('Precision (%)')
axes[1, 1].set_ylim(0, max(updated_most_bought_gender_precisions) + 0.2)

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
methods = [
    "Bestsellers (radek)", "Repurchase (radek)", "Radek combined",
    "Popularity (age group)", "Popularity (avg price group)", 
    "Popularity (max price group)", "Popularity (gender)", 
    "Custom combined", "All methods"
]

x = np.arange(len(methods))  
width = 0.35  

updated_private_scores = [0.00695, 0.02030, 0.01959, 0.00674, 0.00552, 0.00526, 0.00685, 0.00524, 0.01261]
updated_public_scores = [0.00703, 0.02077, 0.02018, 0.00655, 0.00540, 0.00537, 0.00676, 0.00504, 0.01385]

fig, ax = plt.subplots(figsize=(15, 8))
rects1 = ax.bar(x - width/2, updated_private_scores, width, label='Private Score')
rects2 = ax.bar(x + width/2, updated_public_scores, width, label='Public Score')

ax.set_ylabel('Scores')
ax.set_title('MAP@12 Private and Public Scores by Candidate Generation Method')
ax.set_xticks(x)
ax.set_xticklabels(methods, rotation=45, ha='right')
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

plt.show()

# %%
updated_private_scores = [0.00680, 0.02049, 0.02062, 0.00725, 0.00643, 0.00665, 0.00658, 0.00662, 0.01966]
updated_public_scores = [0.00659, 0.02116, 0.02124, 0.00698, 0.00645, 0.00641, 0.00625, 0.00660, 0.02050]

fig, ax = plt.subplots(figsize=(15, 8))
rects1 = ax.bar(x - width/2, updated_private_scores, width, label='Private Score')
rects2 = ax.bar(x + width/2, updated_public_scores, width, label='Public Score')

ax.set_ylabel('Scores')
ax.set_title('MAP@12 Private and Public Scores by Candidate Generation Method + One Hot Encoding')
ax.set_xticks(x)
ax.set_xticklabels(methods, rotation=45, ha='right')
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

plt.show()

# %%
new_methods = [
    "All methods", "All methods (OHE)", "All methods (OHE + #)", 
    "All methods (OHE, #>2)", "All methods (OHE, #>1, Repurchase)", 
    "All methods (OHE, #>2, Repurchase)", "All methods (OHE, #>3, Repurchase)"
]

new_private_scores = [0.01261, 0.01966, 0.01949, 0.00669, 0.02011, 0.02019, 0.01918]
new_public_scores = [0.01385, 0.02050, 0.02039, 0.00665, 0.02058, 0.02083, 0.01965]

x_new = np.arange(len(new_methods)) 

fig, ax = plt.subplots(figsize=(15, 8))
rects1 = ax.bar(x_new - width/2, new_private_scores, width, label='Private Score')
rects2 = ax.bar(x_new + width/2, new_public_scores, width, label='Public Score')

ax.set_ylabel('Scores')
ax.set_title('MAP@12 Private and Public Scores by Candidate Generation Combination Methods')
ax.set_xticks(x_new)
ax.set_xticklabels(new_methods, rotation=45, ha='right')
ax.legend()

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

plt.show()

# %%
import matplotlib.pyplot as plt

num_methods = [1, 2, 3, 4, 5, 6]
counts = [8254266, 2335916, 1863235, 1252597, 838621, 7396]

plt.figure(figsize=(10, 6))
plt.bar(num_methods, counts, color='teal')

plt.xlabel('Number of Methods')
plt.ylabel('Counts')
plt.title('Counts of Number of Methods Used')
plt.yscale('log')  

for i in range(len(num_methods)):
    plt.text(num_methods[i], counts[i], f'{counts[i]:,}', ha = 'center', va = 'bottom')

plt.show()
